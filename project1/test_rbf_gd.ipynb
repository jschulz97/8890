# %%
import numpy as np
import pickle
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
import sys
import os
import random
from importlib import reload
from tqdm import tqdm
import copy

# %% [markdown]
# # Generate Data

# %%
# make data - using uniform dist and ranges
def generate_data(data_ranges, length, epsilon=0.0):
    # get max dims
    dims_x = [np.inf, -np.inf]
    dims_y = [np.inf, -np.inf]
    for clus in data_ranges:
        if(clus[0][0] < dims_x[0]):
            dims_x[0] = clus[0][0]
        if(clus[0][1] > dims_x[1]):
            dims_x[1] = clus[0][1]
        if(clus[1][0] < dims_y[0]):
            dims_y[0] = clus[1][0]
        if(clus[1][1] > dims_y[1]):
            dims_y[1] = clus[1][1]

    # generate
    data = np.zeros((1,2))
    labels = []
    for i,clus in enumerate(data_ranges):
        for j in range(length):
            if(np.random.rand() >= epsilon):
                data = np.append(data, [[
                    np.random.uniform(clus[0][0], clus[0][1]),
                    np.random.uniform(clus[1][0], clus[1][1]),
                ]], axis=0)
                labels.append(i)
            else:
                data = np.append(data, [[
                    np.random.uniform(dims_x[0], dims_x[1]),
                    np.random.uniform(dims_y[0], dims_y[1])
                ]], axis=0)
                labels.append(9)

    data = data[1:]

    return data, labels

# %%
# Split data for display - plt
def split_data(data, labels):
    data_sep = []
    uniq_labels = list(set(sorted(labels)))
    for cl in uniq_labels:
        data_class = np.zeros((1,2))
        for i,lab in enumerate(labels):
            if(cl == lab):
                data_class = np.append(data_class, [data[i]], axis=0)
        data_class = data_class[1:]
        data_sep.append(data_class)
    return data_sep, uniq_labels

# %%
# graph separated data w/ plt
def plt_graph_sep_data(data):
    fig, ax = plt.subplots()
    for cl in data:
        ax.scatter(cl[:,0], cl[:,1])
    plt.show()

# %%
def expand_labels(labels):
    uniqs = list(set(sorted(labels)))
    expanded = []
    for lab in labels:
        new_exp = [0] * len(uniqs)
        new_exp[uniqs.index(lab)] = 1
        expanded.append(new_exp)
    return expanded

# %%
data_ranges = [
    [ [-14.0, -2.0], [6.0, 16.0] ],
    [ [2.0, 15.0],   [-8.0, 6.0] ],
    [ [-12.0, -4.0], [-14.0, -6.0] ]
]
data, labels = generate_data(data_ranges, length=500)

# %% [markdown]
# # Train RBN (Gradient Descent)

# %%
labels_expand = expand_labels(labels)

# %%
import rbn_gd
reload(rbn_gd)

rbnetwork = rbn_gd.RBN(k=100, outputs=1)
error, centers = rbnetwork.train(
    data, 
    labels, 
    alpha=1e-3, 
    epochs=500, 
    batch_size=200, 
    dw_target=.001,
    save_config=True
)

# rbnetwork = rbn.RBN(k=50, outputs=3)
# error = rbnetwork.train(data, labels_expand, alpha=1e-1, epochs=500, batch_size=100, error_target=1e-2)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 500/500 [14:47<00:00,  1.77s/it]
# Completed Training: 500 epochs
# Best Error: 1.7504120661536725e-05

# %%
fig, ax = plt.subplots()
ax.plot(error)

# %% [markdown]
# # Test RBN (resub)

# %%
def classify(pred, labels):
    uniqs = list(set(sorted(labels)))
    min_d = np.inf
    min_i = 0
    for i,l in enumerate(uniqs):
        dis = abs(pred - l)
        if(dis < min_d):
            min_d = dis
            min_i = i
    return uniqs[min_i]

# %%
def test_model(model, data, labels, centers):
    # new_data = np.array([*data[0:2], *data[100:102], *data[200:202]])
    # print(new_data.shape)
    truepos = 0
    preds = []
    for d, l in zip(data, labels):
        pred = model.forward(d)
        pred = classify(pred,labels)
        preds.append(pred)
        if(pred == l):
            truepos += 1

    accuracy = truepos / len(data)
    print('Accuracy:', round(accuracy,2))
    
    data_sep, uniq_labels = split_data(data, preds)
    data_sep.append(centers)
    plt_graph_sep_data(data_sep)
    
    return preds

# %%
preds = test_model(rbnetwork, data, labels, centers)
# Out:
# Accuracy: 0.99

# %%
data_sep, uniq_labels = split_data(data, preds)
plt_graph_sep_data(data_sep)

# %% [markdown]
# # Grid search to map space

# %%
def grid_search(data, model, step=(.5,.5)):
    # generate data
    x = np.arange(min(data[:,0]), max(data[:,0]), step[0])
    y = np.arange(min(data[:,1]), max(data[:,1]), step[1])

    # grid_xy = np.zeros((len(x), len(x)))
    xy_data  = []
    xy_preds = []
    z_preds  = np.zeros((len(x), len(y)))
    z_data   = np.zeros((len(x), len(y)))
    for i in tqdm(range(len(x))):
        for j in range(len(y)):
            pred = model.forward([x[i], y[j]])
            z    = copy.deepcopy(pred)
            pred = classify(pred,labels)
            xy_data.append([x[i], y[j]])
            xy_preds.append(pred)
            z_preds[i,j] = pred
            z_data[i,j]  = z
    
    # predict on grid
    xy_sep, xy_uniq_labels = split_data(xy_data, xy_preds)
    plt_graph_sep_data(xy_sep)
    
    # Plot surface - raw predictions
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    xy_data, xy_preds, z_data = np.array(xy_data), np.array(xy_preds), np.array(z_data)
    Y, X = np.meshgrid(y, x)
    ax.plot_surface(X, Y, z_data, cmap=cm.coolwarm)
    plt.show()

# %%
grid_search(data, rbnetwork, step=(.5,.5))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 58/58 [00:04<00:00, 13.42it/s]

# %%
rbnetwork.centers
# Out:
# array([[ 10.85189526,   1.17722616],
#        [ 14.00111884,  -0.26669606],
#        [  6.20081686,  -0.38564779],
#        [ -2.36288681,   7.35629032],
#        [-11.61280695,  -6.9912418 ],
#        [ -6.02768033,  -9.27883442],
#        [ -7.86048411, -12.92149369],
#        [ 13.10541979,  -4.64855256],
#        [  6.79635669,   0.0211369 ],
#        [ 11.64034602,  -0.63577031],
#        [ -9.01080363,   8.08032138],
#        [  2.07529339,  -2.83750782],
#        [  2.90437088,  -0.86486546],
#        [ -6.39976019, -10.65988458],
#        [ 13.71802663,  -1.44879465],
#        [ -5.78828173, -13.68300023],
#        [  6.94848831,  -3.772483  ],
#        [-12.42388798,  10.23240072],
#        [ -6.656873  ,  11.902996  ],
#        [  3.02101497,   1.64385824],
#        [  9.67384363,  -3.46480884],
#        [ -4.33906351,  11.8776336 ],
#        [ -4.70527319, -12.55044352],
#        [ 10.42983049,   1.80380642],
#        [ -7.10180154, -10.83351201],
#        [ -4.89278287,  10.55097833],
#        [  3.15068755,  -5.76903176],
#        [ -4.0019643 ,   7.28132134],
#        [-13.48704828,   9.90412746],
#        [  9.78045144,  -0.47364833],
#        [  9.00508699,   3.07999369],
#        [ -8.26769173,  11.18766039],
#        [  7.05130127,  -7.80744932],
#        [-10.41042172,  15.15100443],
#        [  8.49976038,  -7.84126091],
#        [-11.22685876, -11.30032135],
#        [ -7.44776886,  -7.53449312],
#        [-10.10959052,  -7.12268531],
#        [ 10.17971676,   2.36493878],
#        [ -8.02734432,  -8.56287803],
#        [ -5.0423178 ,   6.67951524],
#        [  7.48901055,  -1.20539494],
#        [  2.43547275,   4.01768902],
#        [  2.86789555,   4.12042624],
#        [ -7.85798248,  -8.99708342],
#        [ -7.13026368,  16.07404997],
#        [ 11.273978  ,  -1.16488585],
#        [-12.25698378,  12.98880723],
#        [-11.75231105,   9.20323559],
#        [ -6.49189584, -12.48360943],
#        [-10.25372489,   9.87547217],
#        [-11.46081748, -13.2442156 ],
#        [ -3.51481031,  14.55128958],
#        [ -9.05511977, -10.74280838],
#        [ 15.26760732,   3.95135185],
#        [ -4.36994798,   8.54543019],
#        [  9.00764739,  -6.17784632],
#        [  9.30134144,  -4.39951356],
#        [ -5.04055751, -10.43643031],
#        [ -7.45918802,   6.72935552],
#        [  6.31098227,  -3.90694834],
#        [ -9.99530737,  -6.34453154],
#        [-12.29813695,  12.4285677 ],
#        [ -6.97702821, -11.45018348],
#        [ -2.378082  ,   9.54085154],
#        [  6.81859171,   1.65861728],
#        [  6.57756138,   1.8098964 ],
#        [ -3.70865224,  14.13378471],
#        [ -3.62037434,  14.52080991],
#        [ -2.38325679,  12.01986807],
#        [ -7.07100637,  -7.26587155],
#        [  1.96171537,   1.37901735],
#        [ -6.55692883, -10.21100111],
#        [  6.95066033,  -0.38608841],
#        [ -6.78239193,  -7.43107493],
#        [ -3.66339276,   9.6195352 ],
#        [ -5.1378012 , -13.13490314],
#        [ -3.91173466,  11.77506456],
#        [ -3.33274718,   7.29761992],
#        [-10.46502652,  15.44995168],
#        [  2.61508817,  -7.29422257],
#        [ -3.08366391,   9.31069948],
#        [-10.32424974,  -9.65541281],
#        [ 10.73024316,  -5.38088364],
#        [  8.3977779 ,   6.0231014 ],
#        [ -6.2817254 , -12.0739997 ],
#        [ -5.04468105, -11.60930558],
#        [  5.09666995,  -2.99935621],
#        [-11.63913495,  -5.87759867],
#        [  7.05130127,  -7.80744932],
#        [ -6.65581657,  -8.49328299],
#        [ -2.71237205,  10.61677501],
#        [ -9.46117478,   7.24617782],
#        [ -4.46662576,  15.86506274],
#        [  7.41093351,  -6.90146645],
#        [-10.5805625 , -12.10364436],
#        [  4.39944352,   1.05627894],
#        [  4.94635748,   1.74648281],
#        [ -2.62535906,  11.38212399],
#        [ -5.90149401,  13.06125638]])

# %% [markdown]
# # Regression

# %%
x_data = np.linspace(-10, 10, num=1000)
y_data = 0.1*x_data*np.cos(x_data) + 0.1*np.random.normal(size=1000)

# %%
fig,ax = plt.subplots()
ax.scatter(x_data, y_data)
plt.show()

# %%
import rbn_gd
reload(rbn_gd)

rbnetwork = rbn_gd.RBN(k=100, outputs=1)
centers = rbnetwork.train(
    x_data,
    y_data,
    alpha=1e-2, 
    epochs=200, 
    batch_size=200, 
    dw_target=.001,
    save_config=True
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [03:54<00:00,  1.17s/it]
# Completed Training: 200 epochs
# Best Error: 2.348805854354985e-05

# %%
preds = []
for sample in x_data:
    pred = rbnetwork.forward(sample)
    preds.append(pred)
preds = np.array(preds)

fig, ax = plt.subplots()
ax.scatter(x_data, y_data)
ax.scatter(x_data, preds)
plt.show()

# %% [markdown]
# # Iris

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()
x = iris.data[:, [0,3]]  # we only take the first two features.
y = iris.target

# %%
data_sep, uniq_labels = split_data(x, y)
plt_graph_sep_data(data_sep)

# %%
import rbn_gd
reload(rbn_gd)

rbnetwork = rbn_gd.RBN(k=30, outputs=1)
error, centers = rbnetwork.train(
    x,
    y,
    alpha=1e-4, 
    epochs=5000, 
    batch_size=20, 
    dw_target=.0000001,
    save_config=True
)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 5000/5000 [03:27<00:00, 24.14it/s]
# Completed Training: 5000 epochs
# Best Error: 6.383616449048279e-05

# %%
fig, ax = plt.subplots()
ax.plot(error)

# %%
preds = test_model(rbnetwork, x, y, centers)
# Out:
# Accuracy: 0.89

# %%
data_sep, uniq_labels = split_data(x, preds)
plt_graph_sep_data(data_sep)

# %%
grid_search(x, rbnetwork, step=(.05, .05))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 72/72 [00:01<00:00, 52.82it/s]

# %% [markdown]
# # Credit Card Dataset

# %%
import pickle

# %%
with open('data/creditcards.pkl', 'rb') as file:
    creditcards_dict = pickle.load(file)

# %%
# Limit, Age, Marriage, Education
x1 = np.array(creditcards_dict['Limit'][:1000])
x2 = np.array(creditcards_dict['Age'][:1000])
y  = np.array(creditcards_dict['y'][:1000])

data = np.zeros((len(x1), 2))
data[:, 0] = x1
data[:, 1] = x2
data.shape
# Out:
# (1000, 2)

# %%
data_sep, uniq_labels = split_data(data, y)
plt_graph_sep_data(data_sep)

# %%
import rbn_gd
reload(rbn_gd)

rbnetwork = rbn_gd.RBN(k=100, outputs=1)
error, centers = rbnetwork.train(data,y)

# %%
preds = test_model(rbnetwork, data, y, centers)

# %%
data_sep, uniq_labels = split_data(data, preds)
plt_graph_sep_data(data_sep)

# %%
grid_search(data, rbnetwork, step=(10000, 1))
